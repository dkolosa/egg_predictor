# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
data = pd.read_csv('GallusGallusDomesticus.csv')
data
# Out:
#          GallusID GallusBreed  Day  Age  GallusWeight GallusEggColor  \
# 0         Marans1      Marans    1  883          3000          Brown
# 1         Marans1      Marans    2  883          3000          Brown
# 2         Marans1      Marans    3  883          3000          Brown
# 3         Marans1      Marans    4  883          3000          Brown
# 4         Marans1      Marans    5  883          3000          Brown
# ..            ...         ...  ...  ...           ...            ...
# 995  Ameraucana11  Ameraucana    1  384          1800   Bluish-Green
# 996  Ameraucana11  Ameraucana    2  384          1800   Bluish-Green
# 997  Ameraucana11  Ameraucana    3  384          1800   Bluish-Green
# 998  Ameraucana11  Ameraucana    4  384          1800   Bluish-Green
# 999  Ameraucana11  Ameraucana    5  384          1800   Bluish-Green
#
#      GallusEggWeight  AmountOfFeed  EggsPerDay GallusCombType  \
# 0              41.19           114           1         Single
# ...

# %%
data['GallusID'].unique()
# Out:
# array(['Marans1', 'Marans2', 'Marans3', 'Marans4', 'Marans5', 'Marans6',
#        'Marans7', 'Marans8', 'Marans9', 'Marans10', 'Marans11',
#        'Marans12', 'Marans13', 'Marans14', 'Marans15', 'Marans16',
#        'Marans17', 'Marans18', 'Marans19', 'Marans20', 'Marans21',
#        'Marans22', 'Marans23', 'Marans24', 'Marans25', 'Marans26',
#        'Marans27', 'Marans28', 'Marans29', 'Marans30', 'Marans31',
#        'Marans32', 'Marans33', 'Marans34', 'Marans35', 'Marans36',
#        'Marans37', 'Marans38', 'Marans39', 'Marans40', 'Marans41',
#        'Marans42', 'Marans43', 'Marans44', 'Marans45', 'Marans46',
#        'Marans47', 'Marans48', 'Marans49', 'Marans50', 'Marans51',
#        'Marans52', 'Marans53', 'Marans54', 'Marans55', 'Marans56',
#        'Marans57', 'Marans58', 'Marans59', 'Marans60', 'Marans61',
#        'Marans62', 'Marans63', 'Marans64', 'Marans65', 'Marans66',
#        'Marans67', 'Marans68', 'Marans69', 'Marans70', 'Marans71',
# ...

# %%
data.corr()
# Out:
#                        Day       Age  GallusWeight  GallusEggWeight  \
# Day               1.000000  0.001914     -0.082693         0.135436
# Age               0.001914  1.000000      0.052396         0.077701
# GallusWeight     -0.082693  0.052396      1.000000        -0.101810
# GallusEggWeight   0.135436  0.077701     -0.101810         1.000000
# AmountOfFeed     -0.094145  0.128792      0.128234        -0.068021
# EggsPerDay        0.026668 -0.304632      0.095273        -0.037039
# SunLightExposure -0.077250  0.076941      0.161182        -0.025482
#
#                   AmountOfFeed  EggsPerDay  SunLightExposure
# Day                  -0.094145    0.026668         -0.077250
# Age                   0.128792   -0.304632          0.076941
# GallusWeight          0.128234    0.095273          0.161182
# GallusEggWeight      -0.068021   -0.037039         -0.025482
# AmountOfFeed          1.000000   -0.109570          0.007345
# ...

# %%
data.dtypes
# Out:
# GallusID                 object
# GallusBreed              object
# Day                       int64
# Age                       int64
# GallusWeight              int64
# GallusEggColor           object
# GallusEggWeight         float64
# AmountOfFeed              int64
# EggsPerDay                int64
# GallusCombType           object
# SunLightExposure          int64
# GallusClass              object
# GallusLegShanksColor     object
# GallusBeakColor          object
# GallusEarLobesColor      object
# GallusPlumage            object
# dtype: object

# %% [markdown]
# Lets try to perform feature expration and predict the amount of eggs per day a chicken can have

# %%
data_eggs = pd.concat([data['Age'], data['AmountOfFeed'], data['SunLightExposure']], axis=1)
data_labels = data['EggsPerDay']

# %%
data_eggs.tail()
# Out:
#      Age  AmountOfFeed  SunLightExposure
# 995  384           110                 7
# 996  384           110                 7
# 997  384           110                 7
# 998  384           110                 7
# 999  384           110                 7

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import linear_model
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error

# %%
x_train, x_test, y_train, y_test = train_test_split(data_eggs, data_labels, test_size=0.33, random_state=42, shuffle=True)

# %%
lasso = linear_model.Lasso(alpha=.5)
lasso.fit(x_train, y_train)
y_pred = lasso.predict(x_test)
print(f'r2: {r2_score(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
# Out:
# r2: 0.09309668360651979
# MSE: 0.03177909141742444

# %%
ridge = linear_model.Ridge(alpha=.5)
ridge.fit(x_train, y_train)
y_pred = ridge.predict(x_test)
print(f'r2: {r2_score(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
# Out:
# r2: 0.09816384405200118
# MSE: 0.03160153141503732

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
neighbor = KNeighborsRegressor()
neighbor.fit(x_train, y_train)
y_pred = neighbor.predict(x_test)
print(f'r2: {r2_score(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
# Out:
# r2: 1.0
# MSE: 0.0
